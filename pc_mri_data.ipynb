# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dat_file = 'data/ph_013_vd_3.dat'
data = open(dat_file, "rb")

# %%
np_file = np.fromfile(dat_file, dtype="byte")

# %%
plt.hist(np_file)
# Out:
# (array([ 5046876.,  4921269.,  5274499.,  5425346., 31610237., 40002579.,
#          5671686.,  5100320.,  5138658.,  5054738.]),
#  array([-128. , -102.5,  -77. ,  -51.5,  -26. ,   -0.5,   25. ,   50.5,
#           76. ,  101.5,  127. ]),
#  <a list of 10 Patch objects>)

# %%
len(np_file)
# Out:
# 113246208

# %%
np.sqrt(113246208/3)
# Out:
# 6144.0

# %%
np.sqrt(6144)
# Out:
# 78.38367176906169

# %%
plane_1 = np.reshape(np_file[:113246208//3], (6144, 6144))

# %%
plt.matshow(plane_1)
# plt.colorbar()

# %%
plane_2  = np.reshape(np_file[113246208//3:2*(113246208//3)], (6144, 6144))

# %%
plt.matshow(plane_2)

# %%
plane_3  = np.reshape(np_file[2*(113246208//3):], (6144, 6144))
plt.matshow(plane_3)
